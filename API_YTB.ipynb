# %%
from googleapiclient.discovery import build
import pandas as pd

# 1. Cấu hình API
API_KEY = 'AIzaSyDAXeINj0Q_I3pOwtgmJEwWZo92bxnZXt4'
youtube = build('youtube', 'v3', developerKey=API_KEY)

def get_learning_videos(query, max_results=50):
    # 2. Gọi API tìm kiếm video
    search_response = youtube.search().list(
        q=query,
        part='snippet',
        maxResults=max_results,
        type='video',
        relevanceLanguage='vi', # Ưu tiên tiếng Việt
        videoCategoryId='27'    # Category 27 là 'Education'
    ).execute()

    videos = []
    
    for item in search_response['items']:
        video_data = {
            'video_id': item['id']['videoId'],
            'title': item['snippet']['title'],
            'description': item['snippet']['description'],
            'published_at': item['snippet']['publishedAt'],
            'channel_title': item['snippet']['channelTitle']
        }
        videos.append(video_data)
    
    return pd.DataFrame(videos)

# 3. Chạy thử với từ khóa học tập
query_keyword = "lập trình Python cơ bản"
df_videos = get_learning_videos(query_keyword)

# Lưu thành file CSV để nạp vào hệ thống Big Data sau này
df_videos.to_csv('youtube_learning_dataset.csv', index=False, encoding='utf-8-sig')
print(f"Đã lưu {len(df_videos)} video vào file youtube_learning_dataset.csv")
print(df_videos.head())
# Out:
# Đã lưu 50 video vào file youtube_learning_dataset.csv
#       video_id                                              title  \
# 0  6I_ulPytQIc  Lập trình Python - 01. Lập Trình Cơ Bản PYTHON...
# 1  NZj6LI5a9vc  [Khóa học lập trình Python cơ bản] - Bài 1: Gi...
# 2  K7ZKTjmZeWw  Python Là Gì? Tất Tần Tật Về Ngôn Ngữ Lập Trìn...
# 3  d9I6owcZ5zQ  Video trọn bộ hướng dẫn lập trình ngôn ngữ Pyt...
# 4  ULLRzVwYcf0  Ngôn ngữ lập trình là gì? | Bài 1| Lập trình P...
#
#                                          description          published_at  \
# 0  Xem source code, nội dung và các đường link tr...  2021-11-16T22:51:01Z
# 1  [Khóa học lập trình Python cơ bản] - Bài 1: Gi...  2017-09-01T04:45:08Z
# 2  Python là một trong những ngôn ngữ lập trình p...  2024-07-24T13:00:24Z
# 3  Video trọn bộ hướng dẫn lập trình ngôn ngữ Pyt...  2021-07-19T10:32:33Z
# 4  devup #python #laptrinhvien #dev #cntt Ngôn ng...  2022-12-31T02:00:08Z
#
#               channel_title
# 0                      TITV
# ...

# %%
# !pip install google-api-python-client
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.32.0 requires protobuf<5,>=3.20, but you have protobuf 6.33.5 which is incompatible.
# tensorflow-intel 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.33.5 which is incompatible.
# ...
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.7 MB 262.6 kB/s eta 0:00:56
#    ---------------------------------------- 0.0/14.7 MB 262.6 kB/s eta 0:00:56
#    ---------------------------------------- 0.0/14.7 MB 262.6 kB/s eta 0:00:56
#    ---------------------------------------- 0.0/14.7 MB 262.6 kB/s eta 0:00:56
# ...
